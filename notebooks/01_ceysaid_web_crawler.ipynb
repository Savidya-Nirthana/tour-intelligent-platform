# %%
import os
import sys
import json
import time
from pathlib import Path
from urllib.parse import urlparse
from dotenv import load_dotenv
import nest_asyncio


nest_asyncio.apply()

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root / "src"))

load_dotenv(project_root / ".env")

openrouter_key = os.getenv("OPENROUTER_API_KEY")
openai_key = os.getenv("OPENAI_API_KEY")

if not openrouter_key and not openai_key:
    raise EnvironmentError(
        "❌ No API key found!\n"
        "   Add OPENROUTER_API_KEY (recommended) or OPENAI_API_KEY to .env"
    )

provider = "OpenRouter" if openrouter_key else "OpenAI"
print("✅ Environment loaded")
print(f"🌐 Provider: {provider}")
print(f"📁 Project root: {project_root}")
# Out:
# ✅ Environment loaded
# 🌐 Provider: OpenRouter
# 📁 Project root: d:\ai\agentic ai\ceysaid_intelligence_platform

# %%
from infrastructure.config import (
    validate, dump, CRAWL_OUT_DIR, MARKDOWN_DIR
)

try:
    validate()
    dump()
except Exception as e:
    print(f"⚠️  Config note: {e}")

MARKDOWN_DIR.mkdir(parents=True, exist_ok=True)

print(f"\n✅ Output directories ready:")
print(f"   - Markdown: {MARKDOWN_DIR}")
print(f"   - JSONL: {CRAWL_OUT_DIR}")
# Out:
# 2026-03-06 00:19:24.064 | INFO     | infrastructure.config:dump:340 -
# ============================================================
# 2026-03-06 00:19:24.066 | INFO     | infrastructure.config:dump:341 - CONFIGURATION (NON-SECRETS ONLY)
# 2026-03-06 00:19:24.066 | INFO     | infrastructure.config:dump:342 - ============================================================
# 2026-03-06 00:19:24.067 | INFO     | infrastructure.config:dump:344 -
# 🌐 Provider:
# 2026-03-06 00:19:24.067 | INFO     | infrastructure.config:dump:345 -    Provider: openrouter
# 2026-03-06 00:19:24.068 | INFO     | infrastructure.config:dump:346 -    Model Tier: general
# 2026-03-06 00:19:24.068 | INFO     | infrastructure.config:dump:347 -    Chat Model: google/gemini-2.5-flash
# 2026-03-06 00:19:24.068 | INFO     | infrastructure.config:dump:348 -    Embedding Model: openai/text-embedding-3-small
# 2026-03-06 00:19:24.069 | INFO     | infrastructure.config:dump:349 -    Embedding Dimensions: 1536
# 2026-03-06 00:19:24.069 | INFO     | infrastructure.config:dump:351 -
# 📁 Directories & Storage:
# 2026-03-06 00:19:24.069 | INFO     | infrastructure.config:dump:352 -    Data Root: d:\ai\agentic ai\ceysaid_intelligence_platform\data
# 2026-03-06 00:19:24.070 | INFO     | infrastructure.config:dump:353 -    Knowledge Base: d:\ai\agentic ai\ceysaid_intelligence_platform\data\knowledge_base
# 2026-03-06 00:19:24.070 | INFO     | infrastructure.config:dump:354 -    🟡 RAG Vectors: Qdrant Cloud (ceysaid)
# 2026-03-06 00:19:24.071 | INFO     | infrastructure.config:dump:355 -    🟡 CAG Cache: Qdrant Cloud (cag_cache)
# 2026-03-06 00:19:24.071 | INFO     | infrastructure.config:dump:356 -    🟢 ST + LT Memory + CRM: Supabase PostgreSQL
# 2026-03-06 00:19:24.071 | INFO     | infrastructure.config:dump:358 -
# 🔧 Chunking:
# 2026-03-06 00:19:24.072 | INFO     | infrastructure.config:dump:359 -    Fixed Size: 800 tokens
# 2026-03-06 00:19:24.072 | INFO     | infrastructure.config:dump:360 -    Fixed Overlap: 100 tokens
# 2026-03-06 00:19:24.072 | INFO     | infrastructure.config:dump:361 -    Sliding Window: 512 tokens
# 2026-03-06 00:19:24.073 | INFO     | infrastructure.config:dump:362 -    Sliding Stride: 256 tokens
# 2026-03-06 00:19:24.073 | INFO     | infrastructure.config:dump:363 -    Parent-Child: 250 → 1200 tokens
# 2026-03-06 00:19:24.073 | INFO     | infrastructure.config:dump:364 -    Late Chunk: 1000 → 300 tokens
# 2026-03-06 00:19:24.074 | INFO     | infrastructure.config:dump:366 -
# 🔍 Retrieval:
# 2026-03-06 00:19:24.074 | INFO     | infrastructure.config:dump:367 -    Top-K Results: 4
# 2026-03-06 00:19:24.075 | INFO     | infrastructure.config:dump:368 -    Similarity Threshold: 0.7
# 2026-03-06 00:19:24.075 | INFO     | infrastructure.config:dump:370 -
# 💾 CAG (Semantic Cache — Qdrant):
# 2026-03-06 00:19:24.076 | INFO     | infrastructure.config:dump:371 -    Collection: cag_cache
# 2026-03-06 00:19:24.076 | INFO     | infrastructure.config:dump:372 -    Similarity Threshold: 0.9
# 2026-03-06 00:19:24.076 | INFO     | infrastructure.config:dump:373 -    TTL (seconds): 86400
# 2026-03-06 00:19:24.077 | INFO     | infrastructure.config:dump:374 -    Max Cache Size: 1000
# 2026-03-06 00:19:24.077 | SUCCESS  | infrastructure.config:dump:376 -
# 🎯 CRAG:
# 2026-03-06 00:19:24.077 | INFO     | infrastructure.config:dump:377 -    Confidence Threshold: 0.6
# 2026-03-06 00:19:24.078 | INFO     | infrastructure.config:dump:378 -    Expanded K: 8
# 2026-03-06 00:19:24.078 | INFO     | infrastructure.config:dump:380 -
# 🧠 Memory:
# 2026-03-06 00:19:24.078 | INFO     | infrastructure.config:dump:381 -    Short-term Max Turns: 30
# 2026-03-06 00:19:24.079 | INFO     | infrastructure.config:dump:382 -    Long-term Top-K: 5
# 2026-03-06 00:19:24.079 | INFO     | infrastructure.config:dump:383 -    Long-term Threshold: 0.3
# 2026-03-06 00:19:24.079 | INFO     | infrastructure.config:dump:385 -
# 🗄️  Qdrant:
# 2026-03-06 00:19:24.080 | INFO     | infrastructure.config:dump:386 -    Collection: ceysaid
# 2026-03-06 00:19:24.080 | SUCCESS  | infrastructure.config:dump:387 -    URL: ✅ Set
# 2026-03-06 00:19:24.080 | SUCCESS  | infrastructure.config:dump:388 -    API Key: ✅ Set
# 2026-03-06 00:19:24.081 | INFO     | infrastructure.config:dump:390 -
# ============================================================
# ✅ Output directories ready:
#    - Markdown: d:\ai\agentic ai\ceysaid_intelligence_platform\data\ceysaid_markdown
#    - JSONL: d:\ai\agentic ai\ceysaid_intelligence_platform\data

# %%
from applications.ingest_document_service.web_crawler import CEYSAIDWebCrawler

print("CEYSAIDWebCrawler loaded from service layer")
print("Location: application.ingest_document_service.web_crawler")
# Out:
# CEYSAIDWebCrawler loaded from service layer
# Location: application.ingest_document_service.web_crawler

# %% [markdown]
# ## Crawl configuration

# %%
from infrastructure.config import CRAWL_BASE_URL

BASE_URL = CRAWL_BASE_URL or 'https://ceysaid.com/'


START_URLS = [
    # "https://ceysaid.com/visa-services/", 
    # "https://ceysaid.com/", 

    # "https://ceysaid.com/uzbekistan/"
    "https://ceysaid.com/tours/",
    "https://ceysaid.com",
    "https://ceysaid.com/visa-services/"
]

EXCLUDE_PATTERNS = [
        "/login",
        "/register",
        "/contact",
        "/about",
        "/privacy-policy",
        "/terms-of-service",
        "/sitemap",
        "/si",
        "/terms-and-conditions",
        "/careers",
        "/news",
        "/portfolio-property",
        "/city",
        "/blog",
        "/disclaimer",
        "/online-publications",
        "/kyc",
        "/tam",
        "/upcoming-projects",
        "/sell-your-land",
        "/services", 
        "/virtual-tour",
        "/testimonial",
        "/district",
        "/cart", 
        "/my-account",
        
    ]



MAX_DEPTH = 2
REQUEST_DELAY = 2.0
JSON_PATH = CRAWL_OUT_DIR / "ceysaid_corpus.jsonl"

print(f"🌐 Crawl config:")
print(f"   - Start URLs: {len(START_URLS)}")
print(f"   - Max depth: {MAX_DEPTH}")
print(f"   - Request delay: {REQUEST_DELAY}s")
# Out:
# 🌐 Crawl config:
#    - Start URLs: 3
#    - Max depth: 2
#    - Request delay: 2.0s

# %%
start_time = time.time()

crawler = CEYSAIDWebCrawler(base_url=BASE_URL, max_depth=MAX_DEPTH, exclude_patterns=EXCLUDE_PATTERNS)
print(f"\n🚀 Starting crawl at {time.strftime('%H:%M:%S')}\n")
documents = crawler.crawl(START_URLS, request_delay=REQUEST_DELAY)

elapsed = time.time() - start_time
print(f"\n✅ Crawl complete in {elapsed:.1f}s")
print(f"📄 Documents collected: {len(documents)}")
print(f"🔗 URLs visited: {len(crawler.visited)}")
# Out:
# 🚀 Starting crawl at 00:19:27
#
# 🔍 [0] https://ceysaid.com/tours/
#  📎 Added 49 new URLs to queue (depth 1)
#    ⚠️ Skipped (https://ceysaid.com/tours/) - not a property page
# 🔍 [0] https://ceysaid.com/visa-services/
#  📎 Added 19 new URLs to queue (depth 1)
#    ⚠️ Skipped (https://ceysaid.com/visa-services/) - not a property page
# 🔍 [-1] https://ceysaid.com/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 3 new URLs to queue (depth 0)
#  📊 Progress: 0 docs saved, 3 visited, 70 in queue
# 🔍 [-1] https://ceysaid.com/tour-type/daily/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 5 new URLs to queue (depth 0)
#  📊 Progress: 0 docs saved, 4 visited, 72 in queue
# 🔍 [-1] https://ceysaid.com/tour-type/group-departures/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 5 new URLs to queue (depth 0)
#  📊 Progress: 0 docs saved, 5 visited, 76 in queue
# 🔍 [-1] https://ceysaid.com/tour-type/weekend-gateways/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 8 new URLs to queue (depth 0)
#  📊 Progress: 0 docs saved, 6 visited, 83 in queue
# 🔍 [-1] https://ceysaid.com/tour-duration/3-5-days-tour-packages/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 10 new URLs to queue (depth 0)
#  📊 Progress: 0 docs saved, 7 visited, 92 in queue
# 🔍 [-1] https://ceysaid.com/tour-duration/5-7-days-tour-packages/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 8 new URLs to queue (depth 0)
#  📊 Progress: 0 docs saved, 8 visited, 99 in queue
# 🔍 [-1] https://ceysaid.com/tour-duration/8-10-days-tour-packages/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 7 new URLs to queue (depth 0)
#  📊 Progress: 0 docs saved, 9 visited, 105 in queue
# 🔍 [-1] https://ceysaid.com/tour-duration/11-15-days-tour-packages/
#    ⚠️ Skipped (0 chars) - too short
#  📊 Progress: 0 docs saved, 10 visited, 104 in queue
# 🔍 [-1] https://ceysaid.com/tour-duration/stopover-tour-packages/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 1 new URLs to queue (depth 0)
#  📊 Progress: 0 docs saved, 11 visited, 104 in queue
# 🔍 [-1] https://ceysaid.com/location/malaysia-tour-packages/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 1 new URLs to queue (depth 0)
#  📊 Progress: 0 docs saved, 12 visited, 104 in queue
# 🔍 [-1] https://ceysaid.com/location/cambodia-tour-packages/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 3 new URLs to queue (depth 0)
#  📊 Progress: 0 docs saved, 13 visited, 105 in queue
# 🔍 [-1] https://ceysaid.com/location/thailand-tour-packages/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 7 new URLs to queue (depth 0)
#  📊 Progress: 0 docs saved, 14 visited, 111 in queue
# 🔍 [-1] https://ceysaid.com/location/vietnam-tour-packages/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 5 new URLs to queue (depth 0)
#  📊 Progress: 0 docs saved, 15 visited, 115 in queue
# 🔍 [-1] https://ceysaid.com/location/india-tour-packages/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 8 new URLs to queue (depth 0)
#  📊 Progress: 0 docs saved, 16 visited, 122 in queue
# 🔍 [-1] https://ceysaid.com/location/china-tour-packages/
#    ⚠️ Skipped (0 chars) - too short
#  📊 Progress: 0 docs saved, 17 visited, 121 in queue
# 🔍 [-1] https://ceysaid.com/location/japan-tour-packages/
#    ⚠️ Skipped (0 chars) - too short
#  📊 Progress: 0 docs saved, 18 visited, 120 in queue
# 🔍 [-1] https://ceysaid.com/location/united-arab-emirates/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 2 new URLs to queue (depth 0)
#  📊 Progress: 0 docs saved, 19 visited, 121 in queue
# 🔍 [-1] https://ceysaid.com/location/egypt/
#    ⚠️ Skipped (0 chars) - too short
#  📊 Progress: 0 docs saved, 20 visited, 120 in queue
# 🔍 [-1] https://ceysaid.com/location/turkey/
#    ⚠️ Skipped (0 chars) - too short
#  📊 Progress: 0 docs saved, 21 visited, 119 in queue
# 🔍 [-1] https://ceysaid.com/tours
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 3 new URLs to queue (depth 0)
#  📊 Progress: 0 docs saved, 22 visited, 118 in queue
# 🔍 [-1] https://ceysaid.com/tour/solo-trip-to-dubai/
#    ✅ Saved (3634 chars, 47 links found)
#  📊 Progress: 1 docs saved, 23 visited, 117 in queue
# 🔍 [-1] https://ceysaid.com/tour/japan-tokyo-tour/
#    ✅ Saved (3453 chars, 50 links found)
#  📊 Progress: 2 docs saved, 24 visited, 116 in queue
# 🔍 [-1] https://ceysaid.com/tour/northeast-india-tour/
#    ✅ Saved (19131 chars, 50 links found)
#  📊 Progress: 3 docs saved, 25 visited, 115 in queue
# 🔍 [-1] https://ceysaid.com/tour/kashmir-tour-package/
#    ✅ Saved (6269 chars, 50 links found)
#  📊 Progress: 4 docs saved, 26 visited, 114 in queue
# 🔍 [-1] https://ceysaid.com/tour/03-days-hyderabad-tour/
#    ✅ Saved (2097 chars, 50 links found)
#  📊 Progress: 5 docs saved, 27 visited, 113 in queue
# 🔍 [-1] https://ceysaid.com/tour/cochin-pondicherry-chennai-tour/
#    ✅ Saved (3930 chars, 50 links found)
#  📊 Progress: 6 docs saved, 28 visited, 112 in queue
# 🔍 [-1] https://ceysaid.com/tour/tibet-tour-package/
#    ✅ Saved (3844 chars, 50 links found)
#  📊 Progress: 7 docs saved, 29 visited, 111 in queue
# 🔍 [-1] https://ceysaid.com/tour/hong-kong-tour/
#    ✅ Saved (2305 chars, 50 links found)
#  📊 Progress: 8 docs saved, 30 visited, 110 in queue
# 🔍 [-1] https://ceysaid.com/tour/shanghai-tour-package/
#    ✅ Saved (1264 chars, 50 links found)
#  📊 Progress: 9 docs saved, 31 visited, 109 in queue
# 🔍 [-1] https://ceysaid.com/tour/shanghai-tour/
#    ✅ Saved (1235 chars, 50 links found)
#  📊 Progress: 10 docs saved, 32 visited, 108 in queue
# 🔍 [-1] https://ceysaid.com/tour/golden-japan-tour/
#    ✅ Saved (3046 chars, 50 links found)
#  📊 Progress: 11 docs saved, 33 visited, 107 in queue
# 🔍 [-1] https://ceysaid.com/tour/istanbul-cappadocia-tour-package/
#    ✅ Saved (6691 chars, 50 links found)
#  📎 Added 1 new URLs to queue (depth 0)
#  📊 Progress: 12 docs saved, 34 visited, 107 in queue
# 🔍 [-1] https://ceysaid.com/tour/istanbul-kusadas-tour-package/
#    ✅ Saved (7834 chars, 50 links found)
#  📊 Progress: 13 docs saved, 35 visited, 106 in queue
# 🔍 [-1] https://ceysaid.com/tour/istanbul-antalya-tour-package/
#    ✅ Saved (7222 chars, 50 links found)
#  📊 Progress: 14 docs saved, 36 visited, 105 in queue
# 🔍 [-1] https://ceysaid.com/tour/turkey-package-trabzon/
#    ✅ Saved (4507 chars, 50 links found)
#  📊 Progress: 15 docs saved, 37 visited, 104 in queue
# 🔍 [-1] https://ceysaid.com/tours/page/2/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 3 new URLs to queue (depth 0)
#  📊 Progress: 15 docs saved, 38 visited, 106 in queue
# 🔍 [-1] https://ceysaid.com/tours/page/3/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 2 new URLs to queue (depth 0)
#  📊 Progress: 15 docs saved, 39 visited, 107 in queue
# 🔍 [-1] https://ceysaid.com/tours/page/6/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 1 new URLs to queue (depth 0)
#  📊 Progress: 15 docs saved, 40 visited, 107 in queue
# 🔍 [-1] https://ceysaid.com///www.facebook.com/ceysaid/
#    ⚠️ Skipped (0 chars) - too short
#  📊 Progress: 15 docs saved, 41 visited, 106 in queue
# 🔍 [-1] https://ceysaid.com/refunds/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 2 new URLs to queue (depth 0)
#  📊 Progress: 15 docs saved, 42 visited, 105 in queue
# 🔍 [-1] https://ceysaid.com/wp-login.php
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 1 new URLs to queue (depth 0)
#  📊 Progress: 15 docs saved, 43 visited, 105 in queue
# 🔍 [-1] https://ceysaid.com/vietnam-visa/
#    ✅ Saved (887 chars, 39 links found)
#  📎 Added 2 new URLs to queue (depth 0)
#  📊 Progress: 16 docs saved, 44 visited, 106 in queue
# 🔍 [-1] https://ceysaid.com/uzbekistan/
#    ✅ Saved (878 chars, 39 links found)
#  📊 Progress: 17 docs saved, 45 visited, 105 in queue
# 🔍 [-1] https://ceysaid.com/uae-visa/
#    ✅ Saved (806 chars, 39 links found)
#  📊 Progress: 18 docs saved, 46 visited, 104 in queue
# 🔍 [-1] https://ceysaid.com/turkey-visa/
#    ✅ Saved (2569 chars, 39 links found)
#  📊 Progress: 19 docs saved, 47 visited, 103 in queue
# 🔍 [-1] https://ceysaid.com/thailand-visa/
#    ✅ Saved (1396 chars, 39 links found)
#  📊 Progress: 20 docs saved, 48 visited, 102 in queue
# 🔍 [-1] https://ceysaid.com/qatar-visa/
#    ✅ Saved (1949 chars, 39 links found)
#  📊 Progress: 21 docs saved, 49 visited, 101 in queue
# 🔍 [-1] https://ceysaid.com/philippine-visa/
#    ✅ Saved (5260 chars, 39 links found)
#  📊 Progress: 22 docs saved, 50 visited, 100 in queue
# 🔍 [-1] https://ceysaid.com/nepal-visa/
#    ✅ Saved (605 chars, 39 links found)
#  📊 Progress: 23 docs saved, 51 visited, 99 in queue
# 🔍 [-1] https://ceysaid.com/myanmar-visa/
#    ✅ Saved (1613 chars, 39 links found)
#  📊 Progress: 24 docs saved, 52 visited, 98 in queue
# 🔍 [-1] https://ceysaid.com/malaysia-visa/
#    ✅ Saved (2170 chars, 39 links found)
#  📊 Progress: 25 docs saved, 53 visited, 97 in queue
# 🔍 [-1] https://ceysaid.com/laos-visa/
#    ✅ Saved (612 chars, 39 links found)
#  📊 Progress: 26 docs saved, 54 visited, 96 in queue
# 🔍 [-1] https://ceysaid.com/japan-visa/
#    ✅ Saved (2984 chars, 39 links found)
#  📊 Progress: 27 docs saved, 55 visited, 95 in queue
# 🔍 [-1] https://ceysaid.com/indonesia-visa/
#    ✅ Saved (742 chars, 39 links found)
#  📊 Progress: 28 docs saved, 56 visited, 94 in queue
# 🔍 [-1] https://ceysaid.com/indian-visa/
#    ✅ Saved (1826 chars, 39 links found)
#  📊 Progress: 29 docs saved, 57 visited, 93 in queue
# 🔍 [-1] https://ceysaid.com/egypt-visa/
#    ✅ Saved (1707 chars, 39 links found)
#  📊 Progress: 30 docs saved, 58 visited, 92 in queue
# 🔍 [-1] https://ceysaid.com/china-visa/
#    ✅ Saved (2025 chars, 39 links found)
#  📊 Progress: 31 docs saved, 59 visited, 91 in queue
# 🔍 [-1] https://ceysaid.com/cambodia-visa/
#    ✅ Saved (448 chars, 39 links found)
#  📊 Progress: 32 docs saved, 60 visited, 90 in queue
# 🔍 [-1] https://ceysaid.com/bhutan-visa/
#    ✅ Saved (627 chars, 39 links found)
#  📊 Progress: 33 docs saved, 61 visited, 89 in queue
# 🔍 [-1] https://ceysaid.com/azerbaijan-visa/
#    ✅ Saved (448 chars, 39 links found)
#  📊 Progress: 34 docs saved, 62 visited, 88 in queue
# 🔍 [-2] https://ceysaid.com/tour/7-days-vietnam-tour-packages/
#    ✅ Saved (9548 chars, 50 links found)
#  📊 Progress: 35 docs saved, 63 visited, 87 in queue
# 🔍 [-2] https://ceysaid.com/tour/11-days-vietnam-tour-package/
#    ✅ Saved (16609 chars, 50 links found)
#  📊 Progress: 36 docs saved, 64 visited, 86 in queue
# 🔍 [-2] https://ceysaid.com/tour/cambodia-tour-packages/
#    ✅ Saved (7588 chars, 50 links found)
#  📊 Progress: 37 docs saved, 65 visited, 85 in queue
# 🔍 [-2] https://ceysaid.com/tour/bhutan-tour-packages/
#    ✅ Saved (5784 chars, 43 links found)
#  📎 Added 2 new URLs to queue (depth -1)
#  📊 Progress: 38 docs saved, 66 visited, 84 in queue
# 🔍 [-2] https://ceysaid.com/tour/dream-world-bangkok-tour/
#    ✅ Saved (4878 chars, 50 links found)
#  📊 Progress: 39 docs saved, 67 visited, 83 in queue
# 🔍 [-2] https://ceysaid.com/tour/wat-pho-and-royal-grand-palace-tour/
#    ✅ Saved (3677 chars, 50 links found)
#  📊 Progress: 40 docs saved, 68 visited, 82 in queue
# 🔍 [-2] https://ceysaid.com/tour/03-night-singapore-tour-packages/
#    ✅ Saved (2438 chars, 50 links found)
#  📊 Progress: 41 docs saved, 69 visited, 81 in queue
# 🔍 [-2] https://ceysaid.com/tour/09-days-cambodia-group-tour/
#    ✅ Saved (10146 chars, 43 links found)
#  📊 Progress: 42 docs saved, 70 visited, 80 in queue
# 🔍 [-2] https://ceysaid.com/tour/09-days-china-tour/
#    ✅ Saved (1651 chars, 50 links found)
#  📊 Progress: 43 docs saved, 71 visited, 79 in queue
# 🔍 [-2] https://ceysaid.com/tour/vietnam-9-day-tour-package/
#    ✅ Saved (12295 chars, 50 links found)
#  📊 Progress: 44 docs saved, 72 visited, 78 in queue
# 🔍 [-2] https://ceysaid.com/tour/cambodia-laos-classic-tour/
#    ✅ Saved (12816 chars, 50 links found)
#  📊 Progress: 45 docs saved, 73 visited, 77 in queue
# 🔍 [-2] https://ceysaid.com/tour/bangkok-singapore-tour/
#    ✅ Saved (5887 chars, 54 links found)
#  📊 Progress: 46 docs saved, 74 visited, 76 in queue
# 🔍 [-2] https://ceysaid.com/tour/vietnam-and-cambodia-tour/
#    ✅ Saved (7745 chars, 54 links found)
#  📊 Progress: 47 docs saved, 75 visited, 75 in queue
# 🔍 [-2] https://ceysaid.com/tour/vietnam-and-bangkok-tour/
#    ✅ Saved (11206 chars, 54 links found)
#  📊 Progress: 48 docs saved, 76 visited, 74 in queue
# 🔍 [-2] https://ceysaid.com/tour/vietnam-cambodia-tour-packages/
#    ✅ Saved (8014 chars, 54 links found)
#  📊 Progress: 49 docs saved, 77 visited, 73 in queue
# 🔍 [-2] https://ceysaid.com/tour/southern-of-vietnam-and-siemreap/
#    ✅ Saved (6782 chars, 54 links found)
#  📊 Progress: 50 docs saved, 78 visited, 71 in queue
# 🔍 [-2] https://ceysaid.com/tour/thailand-bangkok-tour/
#    ✅ Saved (5890 chars, 54 links found)
#  📊 Progress: 51 docs saved, 79 visited, 70 in queue
# 🔍 [-2] https://ceysaid.com/tour/vietnam-and-cambodia-tours/
#    ✅ Saved (13382 chars, 54 links found)
#  📊 Progress: 52 docs saved, 80 visited, 69 in queue
# 🔍 [-2] https://ceysaid.com/tour/mumbai-shopping-tour/
#    ✅ Saved (5274 chars, 50 links found)
#  📊 Progress: 53 docs saved, 81 visited, 66 in queue
# 🔍 [-2] https://ceysaid.com/tour/04-days-bangkok-tour/
#    ✅ Saved (2410 chars, 50 links found)
#  📊 Progress: 54 docs saved, 82 visited, 65 in queue
# 🔍 [-2] https://ceysaid.com/tour/da-nang-tour-package/
#    ✅ Saved (4356 chars, 50 links found)
#  📊 Progress: 55 docs saved, 83 visited, 64 in queue
# 🔍 [-2] https://ceysaid.com/tour/04-days-siemreap-highlights/
#    ✅ Saved (5061 chars, 50 links found)
#  📊 Progress: 56 docs saved, 84 visited, 63 in queue
# 🔍 [-2] https://ceysaid.com/tour/cairo-tour-packages/
#    ✅ Saved (2443 chars, 50 links found)
#  📎 Added 1 new URLs to queue (depth -1)
#  📊 Progress: 57 docs saved, 85 visited, 63 in queue
# 🔍 [-2] https://ceysaid.com/tour/cambodia-glimpse-tour/
#    ✅ Saved (6481 chars, 50 links found)
#  📊 Progress: 58 docs saved, 86 visited, 62 in queue
# 🔍 [-2] https://ceysaid.com/tour-duration/3-5-days-tour-packages/page/2/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 1 new URLs to queue (depth -1)
#  📊 Progress: 58 docs saved, 87 visited, 62 in queue
# 🔍 [-2] https://ceysaid.com/tour-duration/3-5-days-tour-packages/page/3/
#    ⚠️ Skipped (0 chars) - too short
#  📊 Progress: 58 docs saved, 88 visited, 61 in queue
# 🔍 [-2] https://ceysaid.com/tour/phuket-tour-package/
#    ✅ Saved (3647 chars, 50 links found)
#  📊 Progress: 59 docs saved, 89 visited, 60 in queue
# 🔍 [-2] https://ceysaid.com/tour/turkey-tour-package/
#    ✅ Saved (3301 chars, 50 links found)
#  📊 Progress: 60 docs saved, 90 visited, 59 in queue
# 🔍 [-2] https://ceysaid.com/tour/cambodia-in-depth-tour-package/
#    ✅ Saved (8273 chars, 50 links found)
#  📊 Progress: 61 docs saved, 91 visited, 58 in queue
# 🔍 [-2] https://ceysaid.com/tour/langkawi-penang-tour/
#    ✅ Saved (6273 chars, 50 links found)
#  📊 Progress: 62 docs saved, 92 visited, 57 in queue
# 🔍 [-2] https://ceysaid.com/tour/penang-tour-package/
#    ✅ Saved (5735 chars, 50 links found)
#  📊 Progress: 63 docs saved, 93 visited, 56 in queue
# 🔍 [-2] https://ceysaid.com/tour/phuket-krabi-tour/
#    ✅ Saved (5177 chars, 50 links found)
#  📊 Progress: 64 docs saved, 94 visited, 55 in queue
# 🔍 [-2] https://ceysaid.com/tour-duration/5-7-days-tour-packages/page/2/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 1 new URLs to queue (depth -1)
#  📊 Progress: 64 docs saved, 95 visited, 55 in queue
# 🔍 [-2] https://ceysaid.com/tour-duration/5-7-days-tour-packages/page/3/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 1 new URLs to queue (depth -1)
#  📊 Progress: 64 docs saved, 96 visited, 55 in queue
# 🔍 [-2] https://ceysaid.com/tour/08-days-egypt-tour-package/
#    ✅ Saved (3256 chars, 50 links found)
#  📊 Progress: 65 docs saved, 97 visited, 54 in queue
# 🔍 [-2] https://ceysaid.com/tour/turkey-group-tour/
#    ✅ Saved (6359 chars, 50 links found)
#  📊 Progress: 66 docs saved, 98 visited, 53 in queue
# 🔍 [-2] https://ceysaid.com/tour/beauty-of-vietnam-tour/
#    ✅ Saved (11685 chars, 50 links found)
#  📊 Progress: 67 docs saved, 99 visited, 52 in queue
# 🔍 [-2] https://ceysaid.com/tour/dambadiva-tours-from-sri-lanka/
#    ✅ Saved (5520 chars, 50 links found)
#  📊 Progress: 68 docs saved, 100 visited, 51 in queue
# 🔍 [-2] https://ceysaid.com/tour/cairo-and-sharm-el-sheikh/
#    ✅ Saved (2951 chars, 50 links found)
#  📊 Progress: 69 docs saved, 101 visited, 50 in queue
# 🔍 [-2] https://ceysaid.com/tour/phuket-pattaya-bangkok-tour/
#    ✅ Saved (8672 chars, 54 links found)
#  📊 Progress: 70 docs saved, 102 visited, 49 in queue
# 🔍 [-2] https://ceysaid.com/tour-duration/8-10-days-tour-packages/page/2/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 1 new URLs to queue (depth -1)
#  📊 Progress: 70 docs saved, 103 visited, 49 in queue
# 🔍 [-2] https://ceysaid.com/tour/malaysia-tour-package/
#    ✅ Saved (5139 chars, 50 links found)
#  📊 Progress: 71 docs saved, 104 visited, 47 in queue
# 🔍 [-2] https://ceysaid.com/tour/05-days-cambodia-tour/
#    ✅ Saved (7467 chars, 50 links found)
#  📎 Added 1 new URLs to queue (depth -1)
#  📊 Progress: 72 docs saved, 105 visited, 46 in queue
# 🔍 [-2] https://ceysaid.com/tour/phnom-penh-at-glance/
#    ✅ Saved (3952 chars, 50 links found)
#  📊 Progress: 73 docs saved, 106 visited, 45 in queue
# 🔍 [-2] https://ceysaid.com/tour/andaman-tour-packages/
#    ✅ Saved (3513 chars, 50 links found)
#  📊 Progress: 74 docs saved, 107 visited, 44 in queue
# 🔍 [-2] https://ceysaid.com/tour/bangkok-family-savari/
#    ✅ Saved (3653 chars, 50 links found)
#  📊 Progress: 75 docs saved, 108 visited, 43 in queue
# 🔍 [-2] https://ceysaid.com/tour/phuket-tour-packages/
#    ✅ Saved (2161 chars, 50 links found)
#  📊 Progress: 76 docs saved, 109 visited, 42 in queue
# 🔍 [-2] https://ceysaid.com/tour/pattaya-bangkok-tour/
#    ✅ Saved (5236 chars, 54 links found)
#  📊 Progress: 77 docs saved, 110 visited, 41 in queue
# 🔍 [-2] https://ceysaid.com/tour/phuket-bangkok-tour/
#    ✅ Saved (7106 chars, 50 links found)
#  📊 Progress: 78 docs saved, 111 visited, 40 in queue
# 🔍 [-2] https://ceysaid.com/tour/phuket-koh-samui-tour/
#    ✅ Saved (5792 chars, 50 links found)
#  📊 Progress: 79 docs saved, 112 visited, 39 in queue
# 🔍 [-2] https://ceysaid.com/tour/pattaya-tour-packages/
#    ✅ Saved (2726 chars, 50 links found)
#  📊 Progress: 80 docs saved, 113 visited, 38 in queue
# 🔍 [-2] https://ceysaid.com/tour/northern-vietnam-tour-package/
#    ✅ Saved (6448 chars, 50 links found)
#  📊 Progress: 81 docs saved, 114 visited, 37 in queue
# 🔍 [-2] https://ceysaid.com/tour/northern-vietnam-tours/
#    ✅ Saved (8156 chars, 50 links found)
#  📊 Progress: 82 docs saved, 115 visited, 36 in queue
# 🔍 [-2] https://ceysaid.com/tour/southern-vietnam-tour-packages/
#    ✅ Saved (5075 chars, 50 links found)
#  📊 Progress: 83 docs saved, 116 visited, 35 in queue
# 🔍 [-2] https://ceysaid.com/tour/southern-vietnam-tours/
#    ✅ Saved (6220 chars, 50 links found)
#  📊 Progress: 84 docs saved, 117 visited, 34 in queue
# 🔍 [-2] https://ceysaid.com/tour/sapa-halong-bay-tour/
#    ✅ Saved (4974 chars, 50 links found)
#  📊 Progress: 85 docs saved, 118 visited, 33 in queue
# 🔍 [-2] https://ceysaid.com/tour/04-days-chennai-shopping-tour/
#    ✅ Saved (2736 chars, 50 links found)
#  📊 Progress: 86 docs saved, 119 visited, 32 in queue
# 🔍 [-2] https://ceysaid.com/tour/golden-triangle-tour/
#    ✅ Saved (5466 chars, 50 links found)
#  📊 Progress: 87 docs saved, 120 visited, 31 in queue
# 🔍 [-2] https://ceysaid.com/tour/hyderabad-tour-packages/
#    ✅ Saved (3386 chars, 50 links found)
#  📊 Progress: 88 docs saved, 121 visited, 30 in queue
# 🔍 [-2] https://ceysaid.com/tour/india-tours-from-sri-lanka/
#    ✅ Saved (3521 chars, 50 links found)
#  📊 Progress: 89 docs saved, 122 visited, 29 in queue
# 🔍 [-2] https://ceysaid.com/tour/rajasthan-tour-packages/
#    ✅ Saved (10949 chars, 50 links found)
#  📊 Progress: 90 docs saved, 123 visited, 28 in queue
# 🔍 [-2] https://ceysaid.com/tour/shimla-manali-tour-packages/
#    ✅ Saved (4381 chars, 50 links found)
#  📊 Progress: 91 docs saved, 124 visited, 27 in queue
# 🔍 [-2] https://ceysaid.com/tour/tirupati-tour-packages/
#    ✅ Saved (3918 chars, 50 links found)
#  📊 Progress: 92 docs saved, 125 visited, 26 in queue
# 🔍 [-2] https://ceysaid.com/tour/velankanni-tours-from-sri-lanka/
#    ✅ Saved (3202 chars, 50 links found)
#  📊 Progress: 93 docs saved, 126 visited, 25 in queue
# 🔍 [-2] https://ceysaid.com/tour/abu-dhabi-tour-packages/
#    ✅ Saved (1854 chars, 50 links found)
#  📊 Progress: 94 docs saved, 127 visited, 24 in queue
# 🔍 [-2] https://ceysaid.com/tour/dubai-tour-packages/
#    ✅ Saved (1789 chars, 50 links found)
#  📊 Progress: 95 docs saved, 128 visited, 23 in queue
# 🔍 [-2] https://ceysaid.com/location/turkey-tour-packages/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 3 new URLs to queue (depth -1)
#  📊 Progress: 95 docs saved, 129 visited, 22 in queue
# 🔍 [-2] https://ceysaid.com/tours/page/2
#    ⚠️ Skipped (0 chars) - too short
#  📊 Progress: 95 docs saved, 130 visited, 21 in queue
# 🔍 [-2] https://ceysaid.com/tours/page/1/
#    ⚠️ Skipped (0 chars) - too short
#  📊 Progress: 95 docs saved, 131 visited, 20 in queue
# 🔍 [-2] https://ceysaid.com/tours/page/4/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 1 new URLs to queue (depth -1)
#  📊 Progress: 95 docs saved, 132 visited, 20 in queue
# 🔍 [-2] https://ceysaid.com/tours/page/3
#    ⚠️ Skipped (0 chars) - too short
#  📊 Progress: 95 docs saved, 133 visited, 19 in queue
# 🔍 [-2] https://ceysaid.com/tours/page/5/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 4 new URLs to queue (depth -1)
#  📊 Progress: 95 docs saved, 134 visited, 22 in queue
# 🔍 [-2] https://ceysaid.com/tours/page/6
#    ⚠️ Skipped (0 chars) - too short
#  📊 Progress: 95 docs saved, 135 visited, 21 in queue
# 🔍 [-2] https://ceysaid.com/author/nayananjalee/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 2 new URLs to queue (depth -1)
#  📊 Progress: 95 docs saved, 136 visited, 19 in queue
# 🔍 [-2] https://ceysaid.com/category/visa/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 1 new URLs to queue (depth -1)
#  📊 Progress: 95 docs saved, 137 visited, 19 in queue
# 🔍 [-3] https://ceysaid.com/location/egypt-tour-packages/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 2 new URLs to queue (depth -2)
#  📊 Progress: 95 docs saved, 138 visited, 18 in queue
# 🔍 [-3] https://ceysaid.com/tour-duration/3-5-days-tour-packages/page/1/
#    ⚠️ Skipped (0 chars) - too short
#  📊 Progress: 95 docs saved, 139 visited, 17 in queue
# 🔍 [-3] https://ceysaid.com/tour-duration/5-7-days-tour-packages/page/1/
#    ⚠️ Skipped (0 chars) - too short
#  📊 Progress: 95 docs saved, 140 visited, 16 in queue
# 🔍 [-3] https://ceysaid.com/tour-duration/8-10-days-tour-packages/page/1/
#    ⚠️ Skipped (0 chars) - too short
#  📊 Progress: 95 docs saved, 141 visited, 14 in queue
# 🔍 [-3] https://ceysaid.com/tours/page/4
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 4 new URLs to queue (depth -2)
#  📊 Progress: 95 docs saved, 142 visited, 13 in queue
# 🔍 [-3] https://ceysaid.com/tours/page/5
#    ⚠️ Skipped (0 chars) - too short
#  📊 Progress: 95 docs saved, 143 visited, 12 in queue
# 🔍 [-3] https://ceysaid.com/category/visa/page/2/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 3 new URLs to queue (depth -2)
#  📊 Progress: 95 docs saved, 144 visited, 9 in queue
# 🔍 [-4] https://ceysaid.com/category/visa/page/1/
#    ⚠️ Skipped (0 chars) - too short
#  📎 Added 6 new URLs to queue (depth -3)
#  📊 Progress: 95 docs saved, 145 visited, 8 in queue
#
# ✅ Crawl complete in 1245.3s
# 📄 Documents collected: 95
# 🔗 URLs visited: 145

# %%
for i, doc in enumerate(documents):
    url_path = urlparse(doc['url']).path.strip('/').replace('/', '_')
    if not url_path:
        url_path = 'homepage'
    filename = f"{i:03d}_{url_path}.md"

    md_file = MARKDOWN_DIR/filename
    with open(md_file, 'w', encoding='utf-8') as f:
        f.write(f"# {doc['title']}\n\n")
        f.write(f"**URL**: {doc['url']}\n\n")
        f.write(f"**Depth**: {doc["depth_level"]}\n\n")
        f.write("---\n\n")
        f.write(doc["content"])

print(f"✅ Saved {len(documents)} markdown files to {MARKDOWN_DIR}")

with open(JSON_PATH, 'w', encoding='utf-8') as f:
    for doc in documents:
        f.write(json.dumps(doc, ensure_ascii=False) + '\n')

print(f"✅ Saved JSONL corpus to {JSON_PATH}")
# Out:
# ✅ Saved 95 markdown files to d:\ai\agentic ai\ceysaid_intelligence_platform\data\ceysaid_markdown
# ✅ Saved JSONL corpus to d:\ai\agentic ai\ceysaid_intelligence_platform\data\ceysaid_corpus.jsonl

# %% [markdown]
# ## Check

# %%
import random

print("🔍 Quality Checks:\n")
md_files = list(MARKDOWN_DIR.glob("*.md"))
print(f"1️⃣  Markdown files: {len(md_files)}")

if len(md_files) >= 20:
    print(f"✅ Good! Got {len(md_files)} pages")
elif len(md_files) >= 10:
    print(f"   ⚠️  Only {len(md_files)} pages (site may be small)")
else:
    raise AssertionError(f"❌ Too few pages: {len(md_files)}")

assert JSON_PATH.exists(), f"❌ JSONL not found"
print(f"\n2️⃣  JSONL file: {JSON_PATH.stat().st_size:,} bytes")

with open(JSON_PATH, 'r', encoding='utf-8') as f:
    all_docs = [json.loads(line) for line in f]

samples = random.sample(all_docs, min(3, len(all_docs)))
print(f"\n3️⃣  Random samples:\n")

for i, doc in enumerate(samples, 1):
    print(f"   Sample {i}:")
    print(f"   - URL: {doc['url']}")
    print(f"   - Title: {doc['title']}")
    print(f"   - Words: {len(doc['content'].split())}")
    print()

print("✅ All quality checks passed!")
# Out:
# 🔍 Quality Checks:
#
# 1️⃣  Markdown files: 95
# ✅ Good! Got 95 pages
#
# 2️⃣  JSONL file: 704,395 bytes
#
# 3️⃣  Random samples:
#
#    Sample 1:
#    - URL: https://ceysaid.com/tour/andaman-tour-packages/
#    - Title: Andaman Tour Packages 2025 - Travel with Ceysaid
#    - Words: 562
#
#    Sample 2:
#    - URL: https://ceysaid.com/tour/hong-kong-tour/
#    - Title: 05 Days Hong Kong Tour Package 2025 - Ceysaid
#    - Words: 360
#
#    Sample 3:
#    - URL: https://ceysaid.com/tour/09-days-china-tour/
#    - Title: 09 Days China Tour Package 2025 - Ceysaid
#    - Words: 244
#
# ✅ All quality checks passed!
